# %% [markdown]
# <a href="https://colab.research.google.com/github/cowbay878787/MachineLearning/blob/main/%E3%80%8C0701_Colab_LINE_Bot_with_GEMINI_ipynb%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 10.5 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://twelve-sandfish-afraid.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://twelve-sandfish-afraid.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理人）是一個高度自主的軟體實體或系統，它能夠感知環境、進行推理、做出決策，並採取行動來達成其預設的目標。你可以把它想像成一個擁有「大腦」（AI）和「手腳」（執行動作的能力）的數位助理。
#
# ### 核心概念
#
# 1.  **感知 (Perception):** 能夠從環境中收集資訊。這可以是透過數據輸入、API 呼叫、感測器（如果是實體機器人），或是理解自然語言文本等方式。
# 2.  **推理 (Reasoning):** 處理所感知的資訊，分析情境，並基於這些資訊來思考、規劃和做出決策。這通常涉及複雜的演算法、規則引擎或現在流行的基礎模型（如大型語言模型 LLM）。
# 3.  **行動 (Action):** 根據推理結果採取具體行動，以影響環境或達成目標。這可能是執行程式碼、發送指令、生成文本、控制硬體設備等。
# 4.  **目標導向 (Goal-Oriented):** 每個 AI Agent 都被賦予一個或多個明確的目標，它的一切行為都是為了有效地達成這些目標。
# 5.  **自主性 (Autonomy):** 能夠在沒有人類持續干預的情況下獨立運作，自行決定如何響應環境變化並完成任務。
# 6.  **學習與適應 (Learning & Adaptation - 選配但常見):** 高階的 AI Agent 能夠從經驗中學習，隨著時間的推移改進其表現，並適應新的情境。
#
# ### AI Agent 的運作流程（簡化版）
#
# 1.  **觀察 (Observe):** 感知當前環境的狀態。
# 2.  **分析 (Analyze):** 理解當前狀態與目標之間的差距。
# 3.  **規劃 (Plan):** 制定一系列步驟或策略來縮小這個差距。
# 4.  **執行 (Execute):** 採取行動來實施規劃。
# 5.  **重複 (Repeat):** 觀察行動後的結果，並根據新的環境狀態調整規劃，直到目標達成。
#
# ### 實際應用範例
#
# *   **智能個人助理 (Smart Personal Assistants):** 如 Siri, Alexa, Google Assistant。它們能理解語音指令、執行查詢、設定提醒、控制智能家居設備等。
# *   **智能客服聊天機器人 (Customer Service Chatbots):** 能理解客戶問題、提供資訊、解決常見問題，甚至引導到人工客服。
# *   **自動駕駛汽車 (Autonomous Vehicles):** 這是一個典型的實體 AI Agent，它感知周圍環境（感測器）、規劃路徑、做出駕駛決策（推理）、並控制車輛（行動）。
# *   **金融交易代理人 (Financial Trading Agents):** 監控市場數據、分析趨勢、並根據預設策略自動執行買賣交易。
# *   **工業自動化與機器人 (Industrial Automation & Robotics):** 負責監控生產線、執行重複性任務、檢測產品缺陷等。
# *   **基於大型語言模型的 AI Agent (LLM-powered Agents):** 這是近年來發展最快的領域。這些代理人利用 LLM 的強大推理和生成能力，可以：
#     *   **自主規劃並執行複雜任務:** 例如，一個 agent 可以接收「研究最新的電動車技術並總結其優缺點」的指令，然後自主地去網上搜索、閱讀文獻、提取資訊並撰寫報告。
#     *   **使用工具 (Tool Use):** 這些 agent 不僅限於生成文本，還可以調用外部工具（如瀏覽器、計算器、API、程式碼解釋器）來完成任務，極大地擴展了它們的能力。
#     *   **跨應用協作:** 例如，一個 agent 可以負責從數據庫提取數據，另一個 agent 負責分析數據，第三個 agent 負責生成視覺化報告。
#
# ### 總結
#
# AI Agent 代表了一種更自主、更智能的軟體應用範式。它們不僅僅是執行單一指令的程式，而是能夠根據目標和環境動態調整行為的智能實體，旨在使人類從重複或複雜的任務中解放出來，並在許多領域提供更高效、更智能的解決方案。特別是結合大型語言模型後，AI Agent 的潛力正在被極大地釋放，成為 AI 領域的一個重要發展方向。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Ming Hsin University of Science and Technology, MHUST）是一所位於台灣新竹縣新豐鄉的私立科技大學。以下是其簡要介紹：
#
# 1.  **創校歷史與沿革：**
#     *   創立於**1966年**，最初名為「明新工業專科學校」。
#     *   隨著台灣高等教育的發展，於1997年升格為「明新技術學院」。
#     *   最終在**2002年**改制為現今的「明新科技大學」。
#
# 2.  **地理位置優勢：**
#     *   學校地理位置優越，**鄰近新竹科學園區**及多個工業區，這使其在發展產學合作、提供學生實習與就業機會方面具有得天獨厚的優勢。許多畢業生能直接在竹科或周邊產業就業。
#
# 3.  **教育理念與特色：**
#     *   **實務致用：** 明新科大秉持「實務致用」的教育理念，致力於培養具備專業技能、實作能力及良好職業倫理的科技與服務人才。
#     *   **產學合作：** 學校積極推動與產業界的緊密合作，將產業資源導入教學，提供學生多元的實習機會與業界專題研究，強化學生畢業後的職場競爭力。
#     *   **多元學術領域：** 設有工程學院、管理學院、服務事業學院、設計學院等，涵蓋了工程、資訊、管理、商業、觀光餐旅、設計等多元領域，為學生提供廣泛的專業選擇。
#
# 4.  **教學與研究：**
#     *   課程設計緊密結合產業需求，注重理論與實務的結合。
#     *   鼓勵教師進行應用型研究，並將研究成果轉化為教學內容，提升教學品質。
#     *   重視學生的創新創業能力培養，設有相關輔導機制。
#
# 5.  **國際化與展望：**
#     *   學校積極推動國際交流與合作，與多所國外大學建立姐妹校關係，提供學生海外研修、實習的機會。
#     *   目標是培養具備國際視野及社會責任感的專業人才，為國家社會及產業發展做出貢獻。
#
# 總體而言，明新科技大學以其深厚的實務教學經驗、緊密的產業連結以及對學生就業能力的重視，在台灣技職教育體系中佔有一席之地。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"U43c52fd7c75fca7cc0d739ac44075aad","events":[{"type":"message","message":{"type":"text","id":"616614744178557305","quoteToken":"zfR0tQJ4ZEV-GH16UNyA-uFQQwj9koDrW4_hqOf41xl88S2tN6Xcm18jsBG_RJ9Dy_O6A1aEWKtkre1Q-c4iSh-l1SRfVQTx1hEzPH-JJ06QGzFUi_oGlOjRP_jMRZl3D3zOPBIjWsJNmNvSv-zKLw","markAsReadToken":"G47D8gHW-5ljuXqKA_lNZNd4l2Z1dI7T8uZQkxia5iQjQfAjdku2_ZFZsIYi5YJyyjwSfBf7edJbIwwBqTyJmYAcFR2_IKVeiWE_Q4FyIovoF6G_De-YZmEbabMjgid9IQQWj8zDH3Cdr3p7dgOTOo8gSIesP1z9iCjgUWyqMDeNBNCCE2MRH5uCCZ6EBjBQL_7lwDKaZ-eV-8LtV-oUlQ","text":"簡介明新科技大學"},"webhookEventId":"01KT2XTJ955SEQVN0SZ1BAA281","deliveryContext":{"isRedelivery":false},"timestamp":1780362331944,"source":{"type":"user","userId":"U51821de656e781ae06afc45a00816099"},"replyToken":"71299f5fc9094e6e9a6b0867272eda5d","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [02/Jun/2026 01:05:33] "POST / HTTP/1.1" 200 -
# BODY:  {"destination":"U43c52fd7c75fca7cc0d739ac44075aad","events":[{"type":"message","message":{"type":"text","id":"616614765686424159","quoteToken":"pNshlYEx2tljITv_yie_m1B4ZRm32XfcA3wQV0mJdovOLsMQuuIx6L8_IEbUD2RLa7l17U_FvTSuOpjzMu0gRWMfOhG_fv-cnMvgqZAkCFTiWaw5rsbUANeP2PPSKKZX8BuyMnBDJ_EL4h-BCWMFBQ","markAsReadToken":"t8lrgU9KYg0iveBNwueWLxG5nILO7fSeTaTaRuDWqpwTAO4VV-CpGVP9IgtJ_kNoupx-zZk3pM7lrjTvcWfq78y4U29rvyXGOa0VOkKHfyrqzsvG0ogSao_OxIz-CylQhxnpBgFkr1i_coGcNgH9R85XwjTpTILF-W5zxHbwSYQVjPB4oPxTJNXuV9U14Cg5j1JMIvg0RzdnoWzDpV88Kw","text":"AI 簡介明新科技大學"},"webhookEventId":"01KT2XTYT2C8JNRVEQE18KVA11","deliveryContext":{"isRedelivery":false},"timestamp":1780362344826,"source":{"type":"user","userId":"U51821de656e781ae06afc45a00816099"},"replyToken":"4dc516ce1c664824a81ce0796e12f5bf","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [02/Jun/2026 01:05:57] "POST / HTTP/1.1" 200 -
