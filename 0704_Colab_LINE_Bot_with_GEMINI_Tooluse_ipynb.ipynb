# %% [markdown]
# <a href="https://colab.research.google.com/github/cowbay878787/MachineLearning/blob/main/0704_Colab_LINE_Bot_with_GEMINI_Tooluse_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 5.7 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://twelve-sandfish-afraid.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://twelve-sandfish-afraid.ngrok-free.dev
# True

# %%
from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch

# === 初始化 Google Gemini ===
client = genai.Client(api_key=gemini_api_key)

google_search_tool = Tool(
   google_search=GoogleSearch()
)

chat = client.chats.create(
    model="gemini-2.5-flash",
    config=GenerateContentConfig(
        system_instruction="你是一個中文的AI助手，請用繁體中文回答",
        tools=[google_search_tool],
        response_modalities=["TEXT"],
    )
)

# %%
def stateful_query(payload):
    response = chat.send_message(message=payload)
    return response.text

# %%
result = stateful_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Minghsin University of Science and Technology），簡稱明新科大，是一所位於臺灣新竹縣新豐鄉的私立科技大學。該校地理位置優越，毗鄰新竹工業區與科學園區，利於與產業界進行多項產學合作計畫。
#
# **歷史沿革：**
# 明新科技大學的創校可追溯至1966年，當時以「明新工業專科學校」立案。 隨後於1993年更名為「明新工商專科學校」，並在1997年改制為「明新技術學院」。2002年，學校正式升格並更名為「明新科技大學」，並於2018年經教育部核准更名為「明新學校財團法人明新科技大學」。
#
# **辦學理念與願景：**
# 「明新」之名源自《大學》「在明明德，在新民，在止於至善」的精義，旨在闡揚人類德性與情操，並以培育具備專業學問與優良技術的學生為目標。 學校秉持「堅毅、求新、創造」的校訓，並以「深耕在地、放眼國際」為願景，致力於培養具實務經驗與人文素養的專業人才。 明新科大亦致力於成為「一流產業大學」，強調「跨域整合、務實創新與全人學習」。
#
# **學術組織與特色：**
# 明新科技大學現設有六大學院：半導體學院、工程學院、管理學院、民生學院、人文與設計學院以及共同教育學院。 學校提供20個學系、2個學位學程（含1個博士學位學程）及11個碩士班。 其中，半導體科技博士學位學程於2022年獲教育部核准成立，是該校的第一個博士班。
#
# 為因應產業趨勢，明新科大鎖定半導體、AI、元宇宙、風電綠能等前瞻產業，發展出MUST四大育才特色：多元學習（Multidisciplinary Learning）、全球視野（Universal Perspective）、永續經營（Sustainable Operations）與技術創新（Technological Innovation），引導學生進行跨域學習，成為職場搶手人才。 該校在產官學合作方面表現亮眼，於2022年《遠見》雜誌「企業最愛公私立技職科大調查」中，榮獲兩項「企業最愛」的肯定，畢業生起薪在私立學校中排名第一。 此外，學校也積極推動「智慧生活」的創新服務方式，將生成式AI與AI專案應用導入教學與實習場域，建立智慧零售、智慧金融、智慧製造與智慧商業等實驗室。
#
# 明新科大校園佔地廣闊，交通便利，並提供完善的教學與生活設施，包括圖書館、游泳池、保齡球館等，並優先提供境外生住宿。

# %%
result2 = stateful_query("校長是誰？")
print(result2)
# Out:
# 明新科技大學現任校長是**呂明峯**教授。
#
# 呂明峯教授於2025年1月16日舉行了第11任校長布達暨交接典禮，並於2月1日正式上任。 他在校服務已達34年，擁有豐富的業界經驗與學術背景。 呂明峯校長在任內曾打造全台首座半導體封裝測試類產線，並推動成立半導體學院。
#
# 他提出的學校未來四大方向包括：成為新竹地方人才庫、推動桃竹苗大矽谷的引擎、新南向專班的基地，以及活化資源永續校園。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):
            prompt = text[3:]
            reply_text = stateful_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"U43c52fd7c75fca7cc0d739ac44075aad","events":[{"type":"message","message":{"type":"text","id":"616615572385825025","quoteToken":"RIMEpYl4fIWkN0CXspxYNANj46J1lkbnzY3bXOZsgWD1cUM6I1TRQp9G2Dkl225hnsIhPQ5xBVB8BE1mh9ysXqP72Rs9j0WoESFTvGGnEKwt_5J3h4lGrktMSCGPxkG4Xequ-6Xs5i_X1DzfI_y9kg","markAsReadToken":"7YHh9qX5mMSpQLgJHWd807aSlry75_N6ta98fDKyjzAgJcqvThYOevxtYFYV-F6Ti9DmHYPhNNQszKc0d-JbpoFaRAiNShQYGIHk9A9jPozq9JO5RM6FIlmsxV5bbV6XgjgWbhgwBqi_ySbH4vTprJpztdni3Ibdw_1OYcevpvJFjsmE3r2-yh4qTaHGYMmNFXKKvQyOmtdepVbKSZpENw","text":"AI介紹明新科大，20字內"},"webhookEventId":"01KT2Y9M8A09VRX1ZEBSA62S0H","deliveryContext":{"isRedelivery":false},"timestamp":1780362825679,"source":{"type":"user","userId":"U51821de656e781ae06afc45a00816099"},"replyToken":"697c016a90db4767aea26fcd0dffb047","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [02/Jun/2026 01:13:46] "POST / HTTP/1.1" 200 -
# BODY:  {"destination":"U43c52fd7c75fca7cc0d739ac44075aad","events":[{"type":"message","message":{"type":"text","id":"616615600655171896","quoteToken":"hOBHsvnXhbRAlqEKSX3XUN4mUfv8SK_c7R3kavXLpZkeEHca7LlA1dAg4yH0b49YC9dcAwYLQYWIwfiuTVTTZ9ZRN3uOYmlls4cMyaqafhINN8ocyDmV1Hs7_jhlTtEMedbYBBVUYf9ibx1Hh0qIcg","markAsReadToken":"tImValwljOsZcdhPA4w_CuPQPoCzcObGvpW8ABOgNP9Q3tZGW12HsGvYrTnypMQnlBP5fURET2L012znGsRiyFjuiTGrdTh1TDM0dgWoltgYa9SZEDij3mjc8tw_AuN68oRVWJ-9Gu57nj_OLm4vnnMnMF7tW-g_sjVCj-UQeIjusyWBUKfKz1ShsTwKtBRfDtKgSTNPbTj0PR479pIJpQ","text":"AI介紹明新科大， 20字內"},"webhookEventId":"01KT2YA4TEJD5F9WJ6RTWW4KG2","deliveryContext":{"isRedelivery":false},"timestamp":1780362842448,"source":{"type":"user","userId":"U51821de656e781ae06afc45a00816099"},"replyToken":"e73d9936d44c4fe39fe96752ca106083","mode":"active"}]}
